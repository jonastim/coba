# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from typing import Optional, Sequence

import numpy as np

from coba import CobaRandom, Environments, RandomLearner, Experiment, VowpalSoftmaxLearner, VowpalBagLearner, VowpalEpsilonLearner
from coba import VowpalCoverLearner, VowpalRegcbLearner, VowpalSquarecbLearner, VowpalOffPolicyLearner, CorralLearner
from coba.environments import LambdaSimulation
from coba.experiments.tasks import SimpleEvaluation
from coba.primitives import Context, Action

# %% [markdown]
# # Run Simulation

# %%
from coba.learners.vowpal import VowpalRndLearner


class CustomEnvironment(LambdaSimulation):
    def __init__(self, n_interactions: Optional[int] = 1000):
        super().__init__(n_interactions, self.context, self.actions, self.rewards)
        self.r = CobaRandom(1)

    def actions(self, index: int, context: Context) -> Sequence[Action]:
        """
        actions: A function that should return all valid actions for a given index, context and random state.
        """
        return [0, 1]

    def context(self, index: int) -> Context:
        return {
            "feature_1": self.r.randoms(1)[0],
            "feature_2": self.r.randoms(1)[0],
            "feature_3": self.r.randoms(1)[0]
        }

    def rewards(self, index: int, context: Context, action: Action) -> float:
        # reward centered around 0.5, with feature_1 strongly positively correlating with the reward for the first action 
        # and feature_2 half as much negatively correlating
        reward_probabilities_for_actions = [
            0.5 
                + 1.0 * (context["feature_1"] - 0.5) 
                - 0.5 * (context["feature_2"] - 0.5),
            0.5
        ]
        
        reward_probabilities_for_actions = [min(1.0, max(0.0, prob)) for prob in reward_probabilities_for_actions]
        return np.random.binomial(1, reward_probabilities_for_actions[action])

environments = Environments([CustomEnvironment(5000)]).shuffle(n=4)
learners = [
    VowpalEpsilonLearner(features=[1, 'x', 'a', 'ax']),
    VowpalSoftmaxLearner(features=[1, 'x', 'a', 'ax']),
    VowpalBagLearner(features=[1, 'x', 'a', 'ax']),
    VowpalCoverLearner(features=[1, 'x', 'a', 'ax']),
    VowpalRegcbLearner(features=[1, 'x', 'a', 'ax']),
    VowpalSquarecbLearner(features=[1, 'x', 'a', 'ax']),
    # VowpalOffPolicyLearner(features=[1, 'x', 'a', 'ax']),
    VowpalRndLearner(features=[1, 'x', 'a', 'ax']),
]

# cl = CorralLearner(learners=learners)
# learners.append(cl)
learners.append(RandomLearner())

result = Experiment(
    environments,
    learners,
    evaluation_task=SimpleEvaluation(record=['reward','probability','action','context'])
).run()
# Out:
# 2023-01-26 14:09:29 -- Processing chunk...
# 2023-01-26 14:09:29 --   * Recording Learner 0 parameters... (0.0 seconds) (completed)
# 2023-01-26 14:09:29 --   * Recording Learner 1 parameters... (0.0 seconds) (completed)
# 2023-01-26 14:09:29 --   * Recording Learner 2 parameters... (0.0 seconds) (completed)
# 2023-01-26 14:09:29 --   * Recording Learner 3 parameters... (0.0 seconds) (completed)
# 2023-01-26 14:09:29 --   * Recording Learner 4 parameters... (0.0 seconds) (completed)
# 2023-01-26 14:09:29 --   * Recording Learner 5 parameters... (0.0 seconds) (completed)
# 2023-01-26 14:09:29 --   * Recording Learner 6 parameters... (0.0 seconds) (completed)
# 2023-01-26 14:09:29 --   * Recording Learner 7 parameters... (0.0 seconds) (completed)
# 2023-01-26 14:09:29 --   * Recording Environment 0 statistics... (0.0 seconds) (completed)
# 2023-01-26 14:09:29 --   * Peeking at Environment 0... (0.03 seconds) (completed)
# 2023-01-26 14:09:29 --   * Evaluating Learner 0 on Environment 0... (0.25 seconds) (completed)
# 2023-01-26 14:09:29 --   * Peeking at Environment 0... (0.03 seconds) (completed)
# 2023-01-26 14:09:29 --   * Evaluating Learner 1 on Environment 0... (0.25 seconds) (completed)
# 2023-01-26 14:09:29 --   * Peeking at Environment 0... (0.13 seconds) (completed)
# 2023-01-26 14:09:30 --   * Evaluating Learner 2 on Environment 0... (0.25 seconds) (completed)
# 2023-01-26 14:09:30 --   * Peeking at Environment 0... (0.03 seconds) (completed)
# 2023-01-26 14:09:30 --   * Evaluating Learner 3 on Environment 0... (0.29 seconds) (completed)
# 2023-01-26 14:09:30 --   * Peeking at Environment 0... (0.03 seconds) (completed)
# 2023-01-26 14:09:30 --   * Evaluating Learner 4 on Environment 0... (0.25 seconds) (completed)
# 2023-01-26 14:09:30 --   * Peeking at Environment 0... (0.03 seconds) (completed)
# 2023-01-26 14:09:30 --   * Evaluating Learner 5 on Environment 0... (0.24 seconds) (completed)
# 2023-01-26 14:09:31 --   * Peeking at Environment 0... (0.1 seconds) (completed)
# 2023-01-26 14:09:31 --   * Evaluating Learner 6 on Environment 0... (0.3 seconds) (completed)
# 2023-01-26 14:09:31 --   * Peeking at Environment 0... (0.05 seconds) (completed)
# 2023-01-26 14:09:31 --   * Evaluating Learner 7 on Environment 0... (0.03 seconds) (completed)
# 2023-01-26 14:09:31 --   * Recording Environment 1 statistics... (0.0 seconds) (completed)
# 2023-01-26 14:09:31 --   * Peeking at Environment 1... (0.03 seconds) (completed)
# 2023-01-26 14:09:31 --   * Evaluating Learner 0 on Environment 1... (0.24 seconds) (completed)
# 2023-01-26 14:09:31 --   * Peeking at Environment 1... (0.11 seconds) (completed)
# 2023-01-26 14:09:32 --   * Evaluating Learner 1 on Environment 1... (0.26 seconds) (completed)
# 2023-01-26 14:09:32 --   * Peeking at Environment 1... (0.03 seconds) (completed)
# 2023-01-26 14:09:32 --   * Evaluating Learner 2 on Environment 1... (0.25 seconds) (completed)
# 2023-01-26 14:09:32 --   * Peeking at Environment 1... (0.03 seconds) (completed)
# 2023-01-26 14:09:32 --   * Evaluating Learner 3 on Environment 1... (0.25 seconds) (completed)
# 2023-01-26 14:09:32 --   * Peeking at Environment 1... (0.03 seconds) (completed)
# 2023-01-26 14:09:32 --   * Evaluating Learner 4 on Environment 1... (0.23 seconds) (completed)
# 2023-01-26 14:09:33 --   * Peeking at Environment 1... (0.1 seconds) (completed)
# 2023-01-26 14:09:33 --   * Evaluating Learner 5 on Environment 1... (0.23 seconds) (completed)
# 2023-01-26 14:09:33 --   * Peeking at Environment 1... (0.03 seconds) (completed)
# 2023-01-26 14:09:33 --   * Evaluating Learner 6 on Environment 1... (0.25 seconds) (completed)
# 2023-01-26 14:09:33 --   * Peeking at Environment 1... (0.03 seconds) (completed)
# 2023-01-26 14:09:33 --   * Evaluating Learner 7 on Environment 1... (0.03 seconds) (completed)
# 2023-01-26 14:09:33 --   * Recording Environment 2 statistics... (0.0 seconds) (completed)
# 2023-01-26 14:09:33 --   * Peeking at Environment 2... (0.11 seconds) (completed)
# 2023-01-26 14:09:33 --   * Evaluating Learner 0 on Environment 2... (0.24 seconds) (completed)
# 2023-01-26 14:09:33 --   * Peeking at Environment 2... (0.03 seconds) (completed)
# 2023-01-26 14:09:34 --   * Evaluating Learner 1 on Environment 2... (0.29 seconds) (completed)
# 2023-01-26 14:09:34 --   * Peeking at Environment 2... (0.03 seconds) (completed)
# 2023-01-26 14:09:34 --   * Evaluating Learner 2 on Environment 2... (0.23 seconds) (completed)
# 2023-01-26 14:09:34 --   * Peeking at Environment 2... (0.03 seconds) (completed)
# 2023-01-26 14:09:34 --   * Evaluating Learner 3 on Environment 2... (0.24 seconds) (completed)
# 2023-01-26 14:09:34 --   * Peeking at Environment 2... (0.1 seconds) (completed)
# 2023-01-26 14:09:35 --   * Evaluating Learner 4 on Environment 2... (0.26 seconds) (completed)
# 2023-01-26 14:09:35 --   * Peeking at Environment 2... (0.04 seconds) (completed)
# 2023-01-26 14:09:35 --   * Evaluating Learner 5 on Environment 2... (0.25 seconds) (completed)
# 2023-01-26 14:09:35 --   * Peeking at Environment 2... (0.03 seconds) (completed)
# 2023-01-26 14:09:35 --   * Evaluating Learner 6 on Environment 2... (0.25 seconds) (completed)
# 2023-01-26 14:09:35 --   * Peeking at Environment 2... (0.1 seconds) (completed)
# 2023-01-26 14:09:35 --   * Evaluating Learner 7 on Environment 2... (0.03 seconds) (completed)
# 2023-01-26 14:09:35 --   * Recording Environment 3 statistics... (0.0 seconds) (completed)
# 2023-01-26 14:09:35 --   * Peeking at Environment 3... (0.03 seconds) (completed)
# 2023-01-26 14:09:36 --   * Evaluating Learner 0 on Environment 3... (0.23 seconds) (completed)
# 2023-01-26 14:09:36 --   * Peeking at Environment 3... (0.03 seconds) (completed)
# 2023-01-26 14:09:36 --   * Evaluating Learner 1 on Environment 3... (0.24 seconds) (completed)
# 2023-01-26 14:09:36 --   * Peeking at Environment 3... (0.03 seconds) (completed)
# 2023-01-26 14:09:36 --   * Evaluating Learner 2 on Environment 3... (0.24 seconds) (completed)
# 2023-01-26 14:09:36 --   * Peeking at Environment 3... (0.1 seconds) (completed)
# 2023-01-26 14:09:36 --   * Evaluating Learner 3 on Environment 3... (0.26 seconds) (completed)
# 2023-01-26 14:09:37 --   * Peeking at Environment 3... (0.03 seconds) (completed)
# 2023-01-26 14:09:37 --   * Evaluating Learner 4 on Environment 3... (0.24 seconds) (completed)
# 2023-01-26 14:09:37 --   * Peeking at Environment 3... (0.03 seconds) (completed)
# 2023-01-26 14:09:37 --   * Evaluating Learner 5 on Environment 3... (0.23 seconds) (completed)
# 2023-01-26 14:09:37 --   * Peeking at Environment 3... (0.11 seconds) (completed)
# 2023-01-26 14:09:37 --   * Evaluating Learner 6 on Environment 3... (0.25 seconds) (completed)
# 2023-01-26 14:09:37 --   * Peeking at Environment 3... (0.03 seconds) (completed)
# 2023-01-26 14:09:37 --   * Evaluating Learner 7 on Environment 3... (0.03 seconds) (completed)

# %%
result.plot_learners()

# %%
df = result.interactions.to_pandas()
df.hist(column='reward')
# Out:
# array([[<AxesSubplot: title={'center': 'reward'}>]], dtype=object)

# %%
result.plot_overview()

# %%
result.eval_metrics()
# Out:
#                                                      learners   reward  \
# learner_id
# 6           vw: --cb_explore_adf --rnd 3 --epsilon 0.025 -...  0.58850
# 1           vw: --cb_explore_adf --softmax --lambda 10 --i...  0.58320
# 0           vw: --cb_explore_adf --epsilon 0.05 --interact...  0.57665
# 3           vw: --cb_explore_adf --cover 5 --interactions ...  0.56660
# 2           vw: --cb_explore_adf --bag 5 --interactions ax...  0.55475
# 5           vw: --cb_explore_adf --squarecb --gamma_scale ...  0.54765
# 7                                                 random: N/A  0.50525
# 4           vw: --cb_explore_adf --regcb --interactions ax...  0.49925
#
#              action  probability  environment_variance
# learner_id
# 6           0.50880     0.865316              0.000096
# 1           0.48945     0.731678              0.000061
# 0           0.48165     0.951606              0.000101
# 3           0.51050     0.735421              0.000087
# 2           0.24130     0.943530              0.003579
# 5           0.31700     0.944760              0.000317
# 7           0.49120     0.500000              0.000002
# 4           0.49130     0.500200              0.000045
